# %%
from pathlib import Path
import pandas as pd

BASE_DIR = Path.cwd().parent   # Recommendation_system
DATA_PATH = BASE_DIR / "data" / "processed" / "final_dataset.parquet"

print(DATA_PATH)
print(DATA_PATH.exists())

df = pd.read_parquet(DATA_PATH)
df.head()
# Out:
# c:\Users\MGI\Desktop\Recommendation_system\data\processed\final_dataset.parquet
# True
#                  customer_unique_id                        product_id  \
# 0  871766c5855e863f6eccc05f988b23cb  4244733e06e7ecb4970a6e2683c13e61
# 1  eb28e67c4c0b83846050ddfb8a35d051  e5f2d52b802189ee658865ca93d83a8f
# 2  3818d81c6709e39d06b2738a8d3a2474  c777355d18b72b67abbeef9df44fd0fd
# 3  af861d436cfc08b2c2ddefd0ba074622  7634da152a4610f1595efa32f14722fc
# 4  64b576fb70d441e8f1b2d7d446e483c5  ac6c3623068f30de03045865e4e10089
#
#   customer_state          customer_city product_category_name_english   price  \
# 0             RJ  campos dos goytacazes                    cool_stuff   58.90
# 1             SP        santa fe do sul                      pet_shop  239.90
# 2             MG          para de minas               furniture_decor  199.00
# 3             SP                atibaia                     perfumery   12.99
# ...

# %%
csv_dir = BASE_DIR / "data" / "processed"
csv_path = csv_dir / "final_data.csv"

df.to_csv(csv_path, index=False)
